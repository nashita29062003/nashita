# %% [markdown]
# <a href="https://colab.research.google.com/github/nashita29062003/nashita/blob/main/Area_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016]
category_a = [10, 12, 8, 15, 11, 9, 14]
category_b = [5, 8, 6, 9, 7, 12, 10]
plt.stackplot(years, category_a, category_b, labels=['Category A', 'Category B'], alpha=0.7)
plt.legend(loc='upper left')
plt.xlabel('Years')
plt.ylabel('Values')
plt.title('Area Plot')
plt.grid(True)
plt.tight_layout()
plt.show()
