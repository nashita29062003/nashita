# %% [markdown]
# <a href="https://colab.research.google.com/github/nashita29062003/nashita/blob/main/Line_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
def create_line_plot(x_values, y_values, title, x_label, y_label):
    plt.figure(figsize=(8, 6))
    ax = plt.axes()
    ax.plot(x_values, y_values, marker='o', linestyle='-')
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    plt.show()
x_values = [1, 2, 3, 4, 5]
y_values = [10, 15, 5, 20, 12]
create_line_plot(x_values, y_values, "Line Plot ", "X-axis", "Y-axis")
